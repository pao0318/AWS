# %% [markdown]
# # Solution for Gift Costs

# %%
import time
import numpy as np
import pandas as pd

# %%
with open('gift_costs.txt') as f:
    gift_costs=f.read().split('\n')
    
gift_costs=np.array(gift_costs).astype(int)

# %%
start = time.time()

total_price = 0
for cost in gift_costs:
    if cost < 25:
        total_price += cost * 1.08  # add cost after tax

print(total_price)
print('Duration: {} seconds'.format(time.time() - start))
# Out:
# 1928289.2400000081
# Duration: 0.44835448265075684 seconds

# %% [markdown]
# ## Refactor Code

# %%
start = time.time()

total_price = gift_costs[gift_costs<25].sum()*1.08

print(total_price)
print('Duration: {} seconds'.format(time.time() - start))
# Out:
# 1928289.2400000002
# Duration: 0.009384393692016602 seconds
